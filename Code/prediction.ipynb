# %%
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import load_model

# %%
# Load the Fashion MNIST dataset
(_, _), (x_test, y_test) = fashion_mnist.load_data()

# %%
# Preprocess the data
x_test = x_test.reshape((x_test.shape[0], 28, 28, 1)) / 255.0

# %%
# Load the trained model
model = load_model('final_model.h5')
# Out:
# 2023-07-14 04:24:35.314286: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting:

# %%
# Make predictions
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 2s 4ms/step

# %%
# Get the predicted labels
predicted_labels = tf.argmax(predictions, axis=1).numpy()

# %%
# Compare the predicted labels with the true labels
for i in range(len(x_test)):
    print("True Label: ", y_test[i])
    print("Predicted Label: ", predicted_labels[i])
    print()
# Out:
# True Label:  9
# Predicted Label:  9
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  4
# Predicted Label:  6
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  9
# Predicted Label:  5
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  4
# Predicted Label:  6
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  3
# Predicted Label:  6
#
# True Label:  7
# Predicted Label:  9
#
# True Label:  6
# Predicted Label:  4
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  2
# Predicted Label:  6
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  4
# Predicted Label:  6
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  2
# Predicted Label:  6
#
# True Label:  3
# Predicted Label:  4
#
# True Label:  9
# Predicted Label:  7
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  2
# Predicted Label:  6
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  6
# Predicted Label:  3
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  4
# Predicted Label:  3
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  0
# Predicted Label:  2
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  4
# Predicted Label:  2
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  0
# Predicted Label:  6
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  0
# Predicted Label:  6
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  0
# Predicted Label:  6
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  6
# Predicted Label:  2
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  4
# Predicted Label:  2
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  3
# Predicted Label:  4
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  9
# Predicted Label:  7
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  4
# Predicted Label:  6
#
# True Label:  6
# Predicted Label:  2
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  8
# Predicted Label:  0
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  0
# Predicted Label:  6
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  4
# Predicted Label:  3
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  0
# Predicted Label:  6
#
# True Label:  2
# Predicted Label:  0
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  2
# Predicted Label:  6
#
# True Label:  0
# Predicted Label:  6
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  0
# Predicted Label:  6
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  9
# Predicted Label:  7
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  0
# Predicted Label:  6
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  2
# Predicted Label:  4
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  3
# Predicted Label:  6
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  4
# Predicted Label:  6
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  4
# Predicted Label:  6
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  8
# Predicted Label:  6
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  4
# Predicted Label:  6
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  6
# Predicted Label:  0
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  6
# Predicted Label:  0
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  3
# Predicted Label:  6
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  3
# Predicted Label:  6
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  2
# Predicted Label:  6
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  3
# Predicted Label:  6
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  6
# Predicted Label:  0
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  6
# Predicted Label:  4
#
# True Label:  8
# Predicted Label:  3
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  2
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  8
# Predicted Label:  0
#
# True Label:  2
# Predicted Label:  6
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  3
# Predicted Label:  6
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  6
# Predicted Label:  3
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  3
# Predicted Label:  8
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  6
# Predicted Label:  4
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  2
# Predicted Label:  0
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  3
# Predicted Label:  0
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  2
# Predicted Label:  6
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  1
# Predicted Label:  3
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  3
# Predicted Label:  6
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  2
# Predicted Label:  4
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  6
# Predicted Label:  2
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  2
# Predicted Label:  6
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  0
# Predicted Label:  6
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  0
# Predicted Label:  3
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  2
# Predicted Label:  4
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  4
# Predicted Label:  2
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  6
# Predicted Label:  4
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  0
# Predicted Label:  6
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  0
# Predicted Label:  6
#
# True Label:  6
# Predicted Label:  2
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  6
# Predicted Label:  2
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  3
# Predicted Label:  2
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  0
# Predicted Label:  2
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  2
# Predicted Label:  4
#
# True Label:  6
# Predicted Label:  0
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  3
# Predicted Label:  0
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  3
# Predicted Label:  6
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  0
# Predicted Label:  6
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  0
# Predicted Label:  6
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  6
# Predicted Label:  4
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  5
# Predicted Label:  9
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  4
# Predicted Label:  6
#
# True Label:  6
# Predicted Label:  0
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  6
# Predicted Label:  2
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  8
# Predicted Label:  6
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  6
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  4
# Predicted Label:  6
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  0
# Predicted Label:  3
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  6
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  0
# Predicted Label:  6
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  4
# Predicted Label:  6
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  5
# Predicted Label:  7
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  6
# Predicted Label:  0
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  6
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  6
# Predicted Label:  2
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  6
# Predicted Label:  4
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  2
# Predicted Label:  6
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  2
# Predicted Label:  6
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  6
# Predicted Label:  4
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  2
# Predicted Label:  6
#
# True Label:  0
# Predicted Label:  6
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  0
# Predicted Label:  6
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  6
# Predicted Label:  4
#
# True Label:  2
# Predicted Label:  6
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  2
# Predicted Label:  4
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  8
# Predicted Label:  6
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  4
# Predicted Label:  2
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  8
# Predicted Label:  7
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  0
# Predicted Label:  6
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  3
# Predicted Label:  6
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  4
# Predicted Label:  2
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  9
# Predicted Label:  9
#
# ...
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  0
# Predicted Label:  6
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  6
# Predicted Label:  3
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  0
# Predicted Label:  2
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  2
# Predicted Label:  8
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  8
# Predicted Label:  9
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  6
# Predicted Label:  3
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  0
# Predicted Label:  6
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  4
# Predicted Label:  2
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  6
# Predicted Label:  0
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  1
# Predicted Label:  6
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  0
# Predicted Label:  6
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  9
# Predicted Label:  7
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  6
# Predicted Label:  2
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  6
# Predicted Label:  2
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  6
# Predicted Label:  3
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  9
# Predicted Label:  7
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  0
# Predicted Label:  2
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  6
# Predicted Label:  0
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  4
# Predicted Label:  2
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  0
# Predicted Label:  6
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  9
# Predicted Label:  7
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  0
# Predicted Label:  6
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  9
# Predicted Label:  7
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  8
# Predicted Label:  6
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  0
# Predicted Label:  3
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  1
# Predicted Label:  6
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  0
# Predicted Label:  6
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  6
# Predicted Label:  4
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  7
# Predicted Label:  9
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  8
# Predicted Label:  4
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  0
# Predicted Label:  6
#
# True Label:  2
# Predicted Label:  8
#
# True Label:  6
# Predicted Label:  2
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  6
# Predicted Label:  4
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  4
# Predicted Label:  6
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  8
# Predicted Label:  4
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  2
# Predicted Label:  2
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  6
# Predicted Label:  0
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  0
# Predicted Label:  0
#
# True Label:  0
# Predicted Label:  6
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  3
# Predicted Label:  3
#
# True Label:  2
# Predicted Label:  3
#
# True Label:  7
# Predicted Label:  7
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  4
# Predicted Label:  4
#
# True Label:  5
# Predicted Label:  5
#
# True Label:  6
# Predicted Label:  6
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  9
# Predicted Label:  9
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  8
# Predicted Label:  8
#
# True Label:  1
# Predicted Label:  1
#
# True Label:  5
# Predicted Label:  5
